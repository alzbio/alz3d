# %%
import numpy as np
from pyrosetta import *
from pyrosetta.toolbox import cleanATOM
from pyrosetta import PyMOLMover
init()
fr=rosetta.protocols.relax.FastRelax()
scorefxn = get_score_function()
fr.set_scorefxn(scorefxn)
s24=pose_from_pdb("pdb/s24.pdb")
#fr.max_iter(100)
def mutate(mut,wt):
    loc=int(mut[1:-1])
    to_a=mut[-1:]
    loc=wt.pdb_info().pdb2pose('B', loc)
    m=wt.clone()
    pyrosetta.toolbox.mutants.mutate_residue(m,loc,to_a)
    fr.apply(m)
    m.dump_pdb('pdb/'+mut+'.pdb')
    return m
# Out:
# ┌──────────────────────────────────────────────────────────────────────────────┐
# │                                 PyRosetta-4                                  │
# │              Created in JHU by Sergey Lyskov and PyRosetta Team              │
# │              (C) Copyright Rosetta Commons Member Institutions               │
# │                                                                              │
# │ NOTE: USE OF PyRosetta FOR COMMERCIAL PURPOSES REQUIRE PURCHASE OF A LICENSE │
# │         See LICENSE.PyRosetta.md or email license@uw.edu for details         │
# └──────────────────────────────────────────────────────────────────────────────┘
# PyRosetta-4 2025 [Rosetta PyRosetta4.Release.python39.ubuntu 2025.06+release.029c6a159b896477003a14f78f472d4cd2cead46 2025-02-04T15:14:13] retrieved from: http://www.pyrosetta.org
# core.init: Checking for fconfig files in pwd and ./rosetta/flags
# core.init: Rosetta version: PyRosetta4.Release.python39.ubuntu r394 2025.06+release.029c6a159b 029c6a159b896477003a14f78f472d4cd2cead46 http://www.pyrosetta.org 2025-02-04T15:14:13
# core.init: Rosetta extras: []
# core.init: command: PyRosetta -ex1 -ex2aro -database /home/moqri/.conda/envs/rose/lib/python3.9/site-packages/pyrosetta/database
# basic.random.init_random_generator: 'RNG device' seed mode, using '/dev/urandom', seed=-370074640 seed_offset=0 real_seed=-370074640
# basic.random.init_random_generator: RandomGenerator:init: Normal mode, seed=-370074640 RG_type=mt19937
# protocols.relax.RelaxScriptManager: Reading relax scripts list from database.
# core.scoring.ScoreFunctionFactory: SCOREFUNCTION: ref2015
# core.scoring.etable: Starting energy table calculation
# core.scoring.etable: smooth_etable: changing atr/rep split to bottom of energy well
# core.scoring.etable: smooth_etable: spline smoothing lj etables (maxdis = 6)
# core.scoring.etable: smooth_etable: spline smoothing solvation etables (max_dis = 6)
# core.scoring.etable: Finished calculating energy tables.
# basic.io.database: Database file opened: scoring/score_functions/hbonds/ref2015_params/HBPoly1D.csv
# basic.io.database: Database file opened: scoring/score_functions/hbonds/ref2015_params/HBFadeIntervals.csv
# basic.io.database: Database file opened: scoring/score_functions/hbonds/ref2015_params/HBEval.csv
# basic.io.database: Database file opened: scoring/score_functions/hbonds/ref2015_params/DonStrength.csv
# basic.io.database: Database file opened: scoring/score_functions/hbonds/ref2015_params/AccStrength.csv
# core.chemical.GlobalResidueTypeSet: Finished initializing fa_standard residue type set.  Created 985 residue types
# core.chemical.GlobalResidueTypeSet: Total time to initialize 0.864886 seconds.
# basic.io.database: Database file opened: scoring/score_functions/rama/fd/all.ramaProb
# basic.io.database: Database file opened: scoring/score_functions/rama/fd/prepro.ramaProb
# basic.io.database: Database file opened: scoring/score_functions/omega/omega_ppdep.all.txt
# basic.io.database: Database file opened: scoring/score_functions/omega/omega_ppdep.gly.txt
# basic.io.database: Database file opened: scoring/score_functions/omega/omega_ppdep.pro.txt
# basic.io.database: Database file opened: scoring/score_functions/omega/omega_ppdep.valile.txt
# basic.io.database: Database file opened: scoring/score_functions/P_AA_pp/P_AA
# basic.io.database: Database file opened: scoring/score_functions/P_AA_pp/P_AA_n
# core.scoring.P_AA: shapovalov_lib::shap_p_aa_pp_smooth_level of 1( aka low_smooth ) got activated.
# basic.io.database: Database file opened: scoring/score_functions/P_AA_pp/shapovalov/10deg/kappa131/a20.prop
# protocols.relax.RelaxScriptManager: Looking for MonomerRelax2019.txt
# protocols.relax.RelaxScriptManager: ================== Reading script file: /home/moqri/.conda/envs/rose/lib/python3.9/site-packages/pyrosetta/database/sampling/relax_scripts/MonomerRelax2019.txt ==================
# protocols.relax.RelaxScriptManager: repeat %%nrepeats%%
# protocols.relax.RelaxScriptManager: coord_cst_weight 1.0
# protocols.relax.RelaxScriptManager: scale:fa_rep 0.040
# protocols.relax.RelaxScriptManager: repack
# protocols.relax.RelaxScriptManager: scale:fa_rep 0.051
# protocols.relax.RelaxScriptManager: min 0.01
# protocols.relax.RelaxScriptManager: coord_cst_weight 0.5
# protocols.relax.RelaxScriptManager: scale:fa_rep 0.265
# protocols.relax.RelaxScriptManager: repack
# protocols.relax.RelaxScriptManager: scale:fa_rep 0.280
# protocols.relax.RelaxScriptManager: min 0.01
# protocols.relax.RelaxScriptManager: coord_cst_weight 0.0
# protocols.relax.RelaxScriptManager: scale:fa_rep 0.559
# protocols.relax.RelaxScriptManager: repack
# protocols.relax.RelaxScriptManager: scale:fa_rep 0.581
# protocols.relax.RelaxScriptManager: min 0.01
# protocols.relax.RelaxScriptManager: coord_cst_weight 0.0
# protocols.relax.RelaxScriptManager: scale:fa_rep 1
# protocols.relax.RelaxScriptManager: repack
# protocols.relax.RelaxScriptManager: min 0.00001
# protocols.relax.RelaxScriptManager: accept_to_best
# protocols.relax.RelaxScriptManager: endrepeat
# core.scoring.ScoreFunctionFactory: SCOREFUNCTION: ref2015
# core.import_pose.import_pose: File 'pdb/s24.pdb' automatically determined to be of type PDB
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LYS:CtermProteinFull 25
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  CG  on residue TYR:NtermProteinFull 26
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  CD1 on residue TYR:NtermProteinFull 26
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  CD2 on residue TYR:NtermProteinFull 26
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  CE1 on residue TYR:NtermProteinFull 26
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  CE2 on residue TYR:NtermProteinFull 26
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  CZ  on residue TYR:NtermProteinFull 26
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OH  on residue TYR:NtermProteinFull 26
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ILE:CtermProteinFull 331
# core.pack.pack_missing_sidechains: packing residue number 26 because of missing atom number 6 atom name  CG
# core.pack.task: Packer task: initialize from command line()
# core.scoring.ScoreFunctionFactory: SCOREFUNCTION: ref2015
# basic.io.database: Database file opened: scoring/score_functions/elec_cp_reps.dat
# core.scoring.elec.util: Read 40 countpair representative atoms
# core.pack.dunbrack.RotamerLibrary: shapovalov_lib_fixes_enable option is true.
# core.pack.dunbrack.RotamerLibrary: shapovalov_lib::shap_dun10_smooth_level of 1( aka lowest_smooth ) got activated.
# core.pack.dunbrack.RotamerLibrary: Binary rotamer library selected: /home/moqri/.conda/envs/rose/lib/python3.9/site-packages/pyrosetta/database/rotamer/shapovalov/StpDwn_0-0-0/Dunbrack10.lib.bin
# core.pack.dunbrack.RotamerLibrary: Using Dunbrack library binary file '/home/moqri/.conda/envs/rose/lib/python3.9/site-packages/pyrosetta/database/rotamer/shapovalov/StpDwn_0-0-0/Dunbrack10.lib.bin'.
# core.pack.dunbrack.RotamerLibrary: Dunbrack 2010 library took 0.119791 seconds to load from binary
# core.pack.pack_rotamers: built 6 rotamers at 1 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph

# %%
# %%time
#wt=s24.clone()
#fr.apply(wt)
#wt.dump_pdb('pdb/wt.pdb')
#wt.scores
wt=pose_from_pdb("pdb/wt.pdb")
# Out:
# core.import_pose.import_pose: File 'pdb/wt.pdb' automatically determined to be of type PDB
# CPU times: user 259 ms, sys: 3.02 ms, total: 262 ms
# Wall time: 261 ms

# %%
# %%time
out=['E318G',(1,80),(290,390)]
done=['A99A','I143T','S169L','E280A','L166P']
todo=['V94M','P117L','T147I','R278I','G384A','I439V']
for mut in todo:
    print ('--------------------------------------------------------------------------------------------------------------->',mut)
    m=mutate(mut,wt)
# Out:
# ---------------------------------------------------------------------------------------------------------------> V94M
# core.scoring.ScoreFunctionFactory: SCOREFUNCTION: ref2015
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 9 rotamers at 1 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# protocols.relax.FastRelax: CMD: repeat  -912.969  0  0  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  -912.969  0  0  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1164.68  0  0  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 9534 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -1206.03  0  0  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1197.54  0  0  0.02805
# protocols.relax.FastRelax: CMD: min  -1509.28  1.10553  1.10553  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1509.28  1.10553  1.10553  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -755.811  1.10553  1.10553  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8619 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -815.132  1.10553  1.10553  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -769.534  1.10553  1.10553  0.154
# protocols.relax.FastRelax: CMD: min  -1198.91  0.540245  0.540245  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1198.91  0.540245  0.540245  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -999.188  0.540245  0.540245  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8242 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -1000.39  0.540245  0.540245  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -984.928  0.540245  0.540245  0.31955
# protocols.relax.FastRelax: CMD: min  -1043.06  0.292014  0.292014  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1043.06  0.292014  0.292014  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -875.548  0.292014  0.292014  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 7979 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -876.192  0.292014  0.292014  0.55
# protocols.relax.FastRelax: CMD: min  -915.636  0.0792859  0.0792859  0.55
# protocols.relax.FastRelax: MRP: 0  -915.636  -915.636  0.0792859  0.0792859
# protocols.relax.FastRelax: CMD: accept_to_best  -915.636  0.0792859  0.0792859  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -915.636  0.0792859  0.0792859  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  -915.636  0.0792859  0.0792859  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1166.58  0.0792859  0.0792859  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 9530 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -1204.89  0.0792859  0.0792859  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1196.84  0.0792859  0.0792859  0.02805
# protocols.relax.FastRelax: CMD: min  -1511.18  1.13195  1.13195  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1511.18  1.13195  1.13195  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -754.611  1.13195  1.13195  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8572 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -810.964  1.13195  1.13195  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -766.665  1.13195  1.13195  0.154
# protocols.relax.FastRelax: CMD: min  -1185.37  0.623409  0.623409  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1185.37  0.623409  0.623409  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -987.794  0.623409  0.623409  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8202 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -990.426  0.623409  0.623409  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -975.055  0.623409  0.623409  0.31955
# protocols.relax.FastRelax: CMD: min  -1033.75  0.379033  0.379033  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1033.75  0.379033  0.379033  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -866.805  0.379033  0.379033  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 7954 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -867.744  0.379033  0.379033  0.55
# protocols.relax.FastRelax: CMD: min  -901.714  0.249041  0.249041  0.55
# protocols.relax.FastRelax: MRP: 1  -901.714  -915.636  0.0792859  0.0792859
# protocols.relax.FastRelax: CMD: accept_to_best  -901.714  0.249041  0.249041  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -901.714  0.249041  0.249041  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  -901.714  0.249041  0.249041  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1157.61  0.249041  0.249041  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 9423 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -1212.77  0.249041  0.249041  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1201.21  0.249041  0.249041  0.02805
# protocols.relax.FastRelax: CMD: min  -1508.66  1.18174  1.18174  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1508.66  1.18174  1.18174  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -754.783  1.18174  1.18174  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8698 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -808.9  1.18174  1.18174  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -764.051  1.18174  1.18174  0.154
# protocols.relax.FastRelax: CMD: min  -1180.83  0.667232  0.667232  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1180.83  0.667232  0.667232  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -976.959  0.667232  0.667232  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8158 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -978.117  0.667232  0.667232  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -962.317  0.667232  0.667232  0.31955
# protocols.relax.FastRelax: CMD: min  -1024.35  0.399468  0.399468  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1024.35  0.399468  0.399468  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -855.78  0.399468  0.399468  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8026 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -857.107  0.399468  0.399468  0.55
# protocols.relax.FastRelax: CMD: min  -902.121  0.291302  0.291302  0.55
# protocols.relax.FastRelax: MRP: 2  -902.121  -915.636  0.0792859  0.0792859
# protocols.relax.FastRelax: CMD: accept_to_best  -902.121  0.291302  0.291302  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -902.121  0.291302  0.291302  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  -902.121  0.291302  0.291302  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1149.35  0.291302  0.291302  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 9608 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -1199.76  0.291302  0.291302  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1189.18  0.291302  0.291302  0.02805
# protocols.relax.FastRelax: CMD: min  -1509.46  1.17445  1.17445  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1509.46  1.17445  1.17445  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -759.619  1.17445  1.17445  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8636 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -818.601  1.17445  1.17445  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -773.943  1.17445  1.17445  0.154
# protocols.relax.FastRelax: CMD: min  -1190.95  0.713303  0.713303  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1190.95  0.713303  0.713303  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -989.985  0.713303  0.713303  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 7983 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -990.236  0.713303  0.713303  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -974.793  0.713303  0.713303  0.31955
# protocols.relax.FastRelax: CMD: min  -1033.45  0.485489  0.485489  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1033.45  0.485489  0.485489  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -865.789  0.485489  0.485489  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8045 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -866.613  0.485489  0.485489  0.55
# protocols.relax.FastRelax: CMD: min  -912.27  0.394929  0.394929  0.55
# protocols.relax.FastRelax: MRP: 3  -912.27  -915.636  0.0792859  0.0792859
# protocols.relax.FastRelax: CMD: accept_to_best  -912.27  0.394929  0.394929  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -912.27  0.394929  0.394929  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  -912.27  0.394929  0.394929  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1157.95  0.394929  0.394929  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 9685 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -1200.1  0.394929  0.394929  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1190.66  0.394929  0.394929  0.02805
# protocols.relax.FastRelax: CMD: min  -1502.23  1.15506  1.15506  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1502.23  1.15506  1.15506  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -775.888  1.15506  1.15506  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8642 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -836.15  1.15506  1.15506  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -792.888  1.15506  1.15506  0.154
# protocols.relax.FastRelax: CMD: min  -1188.16  0.67821  0.67821  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1188.16  0.67821  0.67821  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -992.115  0.67821  0.67821  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8113 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -993.581  0.67821  0.67821  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -978.368  0.67821  0.67821  0.31955
# protocols.relax.FastRelax: CMD: min  -1036.34  0.445432  0.445432  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1036.34  0.445432  0.445432  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -872.843  0.445432  0.445432  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8036 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -873.364  0.445432  0.445432  0.55
# protocols.relax.FastRelax: CMD: min  -910.988  0.348297  0.348297  0.55
# protocols.relax.FastRelax: MRP: 4  -910.988  -915.636  0.0792859  0.0792859
# protocols.relax.FastRelax: CMD: accept_to_best  -910.988  0.348297  0.348297  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -910.988  0.348297  0.348297  0.55
# protocols::checkpoint: Deleting checkpoints of FastRelax
# ---------------------------------------------------------------------------------------------------------------> P117L
# core.scoring.ScoreFunctionFactory: SCOREFUNCTION: ref2015
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 2 rotamers at 1 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# protocols.relax.FastRelax: CMD: repeat  -907.091  0  0  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  -907.091  0  0  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1157.65  0  0  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 9524 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -1196.6  0  0  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1187.97  0  0  0.02805
# protocols.relax.FastRelax: CMD: min  -1500.9  1.11555  1.11555  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1500.9  1.11555  1.11555  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -744.458  1.11555  1.11555  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8546 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -803.989  1.11555  1.11555  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -758.685  1.11555  1.11555  0.154
# protocols.relax.FastRelax: CMD: min  -1186.49  0.598576  0.598576  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1186.49  0.598576  0.598576  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -986.702  0.598576  0.598576  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8192 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -988.262  0.598576  0.598576  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -972.822  0.598576  0.598576  0.31955
# protocols.relax.FastRelax: CMD: min  -1031.36  0.381568  0.381568  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1031.36  0.381568  0.381568  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -864.225  0.381568  0.381568  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 7923 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -863.976  0.381568  0.381568  0.55
# protocols.relax.FastRelax: CMD: min  -909.765  0.204596  0.204596  0.55
# protocols.relax.FastRelax: MRP: 0  -909.765  -909.765  0.204596  0.204596
# protocols.relax.FastRelax: CMD: accept_to_best  -909.765  0.204596  0.204596  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -909.765  0.204596  0.204596  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  -909.765  0.204596  0.204596  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1157.04  0.204596  0.204596  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 9408 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -1195.73  0.204596  0.204596  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1186.37  0.204596  0.204596  0.02805
# protocols.relax.FastRelax: CMD: min  -1496.5  1.14215  1.14215  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1496.5  1.14215  1.14215  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -734.098  1.14215  1.14215  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8518 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -795.462  1.14215  1.14215  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -749.768  1.14215  1.14215  0.154
# protocols.relax.FastRelax: CMD: min  -1188.07  0.605293  0.605293  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1188.07  0.605293  0.605293  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -990.889  0.605293  0.605293  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8218 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -992.155  0.605293  0.605293  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -976.914  0.605293  0.605293  0.31955
# protocols.relax.FastRelax: CMD: min  -1032.73  0.374291  0.374291  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1032.73  0.374291  0.374291  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -866.575  0.374291  0.374291  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8010 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -867.341  0.374291  0.374291  0.55
# protocols.relax.FastRelax: CMD: min  -908.742  0.291359  0.291359  0.55
# protocols.relax.FastRelax: MRP: 1  -908.742  -909.765  0.204596  0.204596
# protocols.relax.FastRelax: CMD: accept_to_best  -908.742  0.291359  0.291359  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -908.742  0.291359  0.291359  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  -908.742  0.291359  0.291359  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1153.95  0.291359  0.291359  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 9447 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -1194.82  0.291359  0.291359  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1184.57  0.291359  0.291359  0.02805
# protocols.relax.FastRelax: CMD: min  -1496.47  1.17302  1.17302  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1496.47  1.17302  1.17302  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -730.811  1.17302  1.17302  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8464 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -795.267  1.17302  1.17302  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -749.014  1.17302  1.17302  0.154
# protocols.relax.FastRelax: CMD: min  -1190.15  0.604161  0.604161  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1190.15  0.604161  0.604161  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -990.663  0.604161  0.604161  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8223 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -992.152  0.604161  0.604161  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -976.833  0.604161  0.604161  0.31955
# protocols.relax.FastRelax: CMD: min  -1032.98  0.382803  0.382803  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1032.98  0.382803  0.382803  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -864.263  0.382803  0.382803  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8035 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -865.163  0.382803  0.382803  0.55
# protocols.relax.FastRelax: CMD: min  -908.38  0.285085  0.285085  0.55
# protocols.relax.FastRelax: MRP: 2  -908.38  -909.765  0.204596  0.204596
# protocols.relax.FastRelax: CMD: accept_to_best  -908.38  0.285085  0.285085  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -908.38  0.285085  0.285085  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  -908.38  0.285085  0.285085  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1155.55  0.285085  0.285085  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 9564 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -1193.64  0.285085  0.285085  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1182.43  0.285085  0.285085  0.02805
# protocols.relax.FastRelax: CMD: min  -1500.87  1.17752  1.17752  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1500.87  1.17752  1.17752  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -731.397  1.17752  1.17752  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8506 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -793.454  1.17752  1.17752  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -747.124  1.17752  1.17752  0.154
# protocols.relax.FastRelax: CMD: min  -1188  0.680247  0.680247  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1188  0.680247  0.680247  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -985.393  0.680247  0.680247  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8151 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -986.46  0.680247  0.680247  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -970.815  0.680247  0.680247  0.31955
# protocols.relax.FastRelax: CMD: min  -1028.53  0.475701  0.475701  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1028.53  0.475701  0.475701  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -858.126  0.475701  0.475701  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 7988 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -858.771  0.475701  0.475701  0.55
# protocols.relax.FastRelax: CMD: min  -901.227  0.358233  0.358233  0.55
# protocols.relax.FastRelax: MRP: 3  -901.227  -909.765  0.204596  0.204596
# protocols.relax.FastRelax: CMD: accept_to_best  -901.227  0.358233  0.358233  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -901.227  0.358233  0.358233  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  -901.227  0.358233  0.358233  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1154.02  0.358233  0.358233  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 9574 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -1192.75  0.358233  0.358233  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1183.38  0.358233  0.358233  0.02805
# protocols.relax.FastRelax: CMD: min  -1512.24  1.19384  1.19384  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1512.24  1.19384  1.19384  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -749.388  1.19384  1.19384  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8440 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -801.741  1.19384  1.19384  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -754.966  1.19384  1.19384  0.154
# protocols.relax.FastRelax: CMD: min  -1188.94  0.671398  0.671398  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1188.94  0.671398  0.671398  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -985.711  0.671398  0.671398  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8151 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -987.605  0.671398  0.671398  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -971.804  0.671398  0.671398  0.31955
# protocols.relax.FastRelax: CMD: min  -1031  0.464536  0.464536  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1031  0.464536  0.464536  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -859.764  0.464536  0.464536  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 7900 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -860.08  0.464536  0.464536  0.55
# protocols.relax.FastRelax: CMD: min  -904.046  0.361393  0.361393  0.55
# protocols.relax.FastRelax: MRP: 4  -904.046  -909.765  0.204596  0.204596
# protocols.relax.FastRelax: CMD: accept_to_best  -904.046  0.361393  0.361393  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -904.046  0.361393  0.361393  0.55
# protocols::checkpoint: Deleting checkpoints of FastRelax
# ---------------------------------------------------------------------------------------------------------------> T147I
# core.scoring.ScoreFunctionFactory: SCOREFUNCTION: ref2015
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1 rotamers at 1 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# protocols.relax.FastRelax: CMD: repeat  -881.272  0  0  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  -881.272  0  0  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1168.63  0  0  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 9422 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -1210.12  0  0  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1200.64  0  0  0.02805
# protocols.relax.FastRelax: CMD: min  -1517.3  1.14768  1.14768  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1517.3  1.14768  1.14768  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -739.306  1.14768  1.14768  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8503 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -788.776  1.14768  1.14768  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -740.683  1.14768  1.14768  0.154
# protocols.relax.FastRelax: CMD: min  -1195.09  0.615471  0.615471  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1195.09  0.615471  0.615471  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -989.768  0.615471  0.615471  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8138 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -991.348  0.615471  0.615471  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -975.377  0.615471  0.615471  0.31955
# protocols.relax.FastRelax: CMD: min  -1036.02  0.372125  0.372125  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1036.02  0.372125  0.372125  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -866.403  0.372125  0.372125  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 7938 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -867.652  0.372125  0.372125  0.55
# protocols.relax.FastRelax: CMD: min  -907.782  0.261018  0.261018  0.55
# protocols.relax.FastRelax: MRP: 0  -907.782  -907.782  0.261018  0.261018
# protocols.relax.FastRelax: CMD: accept_to_best  -907.782  0.261018  0.261018  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -907.782  0.261018  0.261018  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  -907.782  0.261018  0.261018  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1159.38  0.261018  0.261018  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 9378 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -1197.19  0.261018  0.261018  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1189.77  0.261018  0.261018  0.02805
# protocols.relax.FastRelax: CMD: min  -1520.6  1.1603  1.1603  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1520.6  1.1603  1.1603  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -769.201  1.1603  1.1603  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8617 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -817.861  1.1603  1.1603  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -771.515  1.1603  1.1603  0.154
# protocols.relax.FastRelax: CMD: min  -1195.11  0.597371  0.597371  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1195.11  0.597371  0.597371  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -990.221  0.597371  0.597371  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8166 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -991.272  0.597371  0.597371  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -975.483  0.597371  0.597371  0.31955
# protocols.relax.FastRelax: CMD: min  -1032.52  0.386104  0.386104  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1032.52  0.386104  0.386104  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -858.317  0.386104  0.386104  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8050 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -860.295  0.386104  0.386104  0.55
# protocols.relax.FastRelax: CMD: min  -912.768  0.252204  0.252204  0.55
# protocols.relax.FastRelax: MRP: 1  -912.768  -912.768  0.252204  0.252204
# protocols.relax.FastRelax: CMD: accept_to_best  -912.768  0.252204  0.252204  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -912.768  0.252204  0.252204  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  -912.768  0.252204  0.252204  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1160.66  0.252204  0.252204  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 9426 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -1196.88  0.252204  0.252204  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1189.11  0.252204  0.252204  0.02805
# protocols.relax.FastRelax: CMD: min  -1519.88  1.14364  1.14364  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1519.88  1.14364  1.14364  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -754.863  1.14364  1.14364  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8565 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -802.68  1.14364  1.14364  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -756.169  1.14364  1.14364  0.154
# protocols.relax.FastRelax: CMD: min  -1193.37  0.649655  0.649655  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1193.37  0.649655  0.649655  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -991.639  0.649655  0.649655  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8163 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -993.551  0.649655  0.649655  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -977.869  0.649655  0.649655  0.31955
# protocols.relax.FastRelax: CMD: min  -1036.44  0.451123  0.451123  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1036.44  0.451123  0.451123  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -867.128  0.451123  0.451123  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 7859 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -866.627  0.451123  0.451123  0.55
# protocols.relax.FastRelax: CMD: min  -912.404  0.392824  0.392824  0.55
# protocols.relax.FastRelax: MRP: 2  -912.404  -912.768  0.252204  0.252204
# protocols.relax.FastRelax: CMD: accept_to_best  -912.404  0.392824  0.392824  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -912.404  0.392824  0.392824  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  -912.404  0.392824  0.392824  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1161.61  0.392824  0.392824  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 9435 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -1200.16  0.392824  0.392824  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1191.61  0.392824  0.392824  0.02805
# protocols.relax.FastRelax: CMD: min  -1507.43  1.14366  1.14366  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1507.43  1.14366  1.14366  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -763.391  1.14366  1.14366  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8570 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -811.444  1.14366  1.14366  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -765.703  1.14366  1.14366  0.154
# protocols.relax.FastRelax: CMD: min  -1191.29  0.623342  0.623342  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1191.29  0.623342  0.623342  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -994.488  0.623342  0.623342  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8140 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -996.444  0.623342  0.623342  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -981.478  0.623342  0.623342  0.31955
# protocols.relax.FastRelax: CMD: min  -1041.81  0.445183  0.445183  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1041.81  0.445183  0.445183  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -879.581  0.445183  0.445183  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 7934 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -879.505  0.445183  0.445183  0.55
# protocols.relax.FastRelax: CMD: min  -917.236  0.491104  0.491104  0.55
# protocols.relax.FastRelax: MRP: 3  -917.236  -917.236  0.491104  0.491104
# protocols.relax.FastRelax: CMD: accept_to_best  -917.236  0.491104  0.491104  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -917.236  0.491104  0.491104  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  -917.236  0.491104  0.491104  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1163.38  0.491104  0.491104  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 9612 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -1202.91  0.491104  0.491104  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1193.83  0.491104  0.491104  0.02805
# protocols.relax.FastRelax: CMD: min  -1503.44  1.15805  1.15805  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1503.44  1.15805  1.15805  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -754.245  1.15805  1.15805  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8512 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -814.659  1.15805  1.15805  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -770.909  1.15805  1.15805  0.154
# protocols.relax.FastRelax: CMD: min  -1188.97  0.689508  0.689508  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1188.97  0.689508  0.689508  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -992.941  0.689508  0.689508  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8177 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -994.713  0.689508  0.689508  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -979.568  0.689508  0.689508  0.31955
# protocols.relax.FastRelax: CMD: min  -1036.94  0.508218  0.508218  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1036.94  0.508218  0.508218  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -872.44  0.508218  0.508218  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8055 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -873.163  0.508218  0.508218  0.55
# protocols.relax.FastRelax: CMD: min  -913.438  0.488147  0.488147  0.55
# protocols.relax.FastRelax: MRP: 4  -913.438  -917.236  0.491104  0.491104
# protocols.relax.FastRelax: CMD: accept_to_best  -913.438  0.488147  0.488147  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -913.438  0.488147  0.488147  0.55
# protocols::checkpoint: Deleting checkpoints of FastRelax
# ---------------------------------------------------------------------------------------------------------------> R278I
# core.scoring.ScoreFunctionFactory: SCOREFUNCTION: ref2015
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 2 rotamers at 1 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# protocols.relax.FastRelax: CMD: repeat  -908.921  0  0  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  -908.921  0  0  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1161.99  0  0  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 9507 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -1202.67  0  0  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1194.3  0  0  0.02805
# protocols.relax.FastRelax: CMD: min  -1509.45  1.12783  1.12783  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1509.45  1.12783  1.12783  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -752.693  1.12783  1.12783  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8576 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -810.158  1.12783  1.12783  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -764.067  1.12783  1.12783  0.154
# protocols.relax.FastRelax: CMD: min  -1197.22  0.556921  0.556921  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1197.22  0.556921  0.556921  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -995.99  0.556921  0.556921  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8290 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -997.721  0.556921  0.556921  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -982.24  0.556921  0.556921  0.31955
# protocols.relax.FastRelax: CMD: min  -1039.23  0.322572  0.322572  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1039.23  0.322572  0.322572  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -868.923  0.322572  0.322572  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8005 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -869.124  0.322572  0.322572  0.55
# protocols.relax.FastRelax: CMD: min  -912.69  0.177594  0.177594  0.55
# protocols.relax.FastRelax: MRP: 0  -912.69  -912.69  0.177594  0.177594
# protocols.relax.FastRelax: CMD: accept_to_best  -912.69  0.177594  0.177594  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -912.69  0.177594  0.177594  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  -912.69  0.177594  0.177594  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1164.6  0.177594  0.177594  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 9563 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -1201.13  0.177594  0.177594  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1192.5  0.177594  0.177594  0.02805
# protocols.relax.FastRelax: CMD: min  -1505.21  1.13245  1.13245  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1505.21  1.13245  1.13245  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -742.963  1.13245  1.13245  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8655 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -798.519  1.13245  1.13245  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -752.234  1.13245  1.13245  0.154
# protocols.relax.FastRelax: CMD: min  -1191.17  0.678313  0.678313  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1191.17  0.678313  0.678313  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -986.44  0.678313  0.678313  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8066 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -988.22  0.678313  0.678313  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -972.396  0.678313  0.678313  0.31955
# protocols.relax.FastRelax: CMD: min  -1029.85  0.459034  0.459034  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1029.85  0.459034  0.459034  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -854.803  0.459034  0.459034  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 7879 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -855.518  0.459034  0.459034  0.55
# protocols.relax.FastRelax: CMD: min  -906.624  0.251618  0.251618  0.55
# protocols.relax.FastRelax: MRP: 1  -906.624  -912.69  0.177594  0.177594
# protocols.relax.FastRelax: CMD: accept_to_best  -906.624  0.251618  0.251618  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -906.624  0.251618  0.251618  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  -906.624  0.251618  0.251618  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1158.05  0.251618  0.251618  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 9551 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -1197.34  0.251618  0.251618  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1189.76  0.251618  0.251618  0.02805
# protocols.relax.FastRelax: CMD: min  -1509.65  1.14522  1.14522  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1509.65  1.14522  1.14522  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -757.697  1.14522  1.14522  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8607 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -817.598  1.14522  1.14522  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -772.449  1.14522  1.14522  0.154
# protocols.relax.FastRelax: CMD: min  -1193.73  0.601008  0.601008  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1193.73  0.601008  0.601008  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -991.846  0.601008  0.601008  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8238 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -993.456  0.601008  0.601008  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -977.898  0.601008  0.601008  0.31955
# ...
# core.pack.pack_rotamers: built 9507 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -1208.44  0.341289  0.341289  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1200.36  0.341289  0.341289  0.02805
# protocols.relax.FastRelax: CMD: min  -1516.73  1.1763  1.1763  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1516.73  1.1763  1.1763  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -761.362  1.1763  1.1763  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8550 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -814.362  1.1763  1.1763  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -768.319  1.1763  1.1763  0.154
# protocols.relax.FastRelax: CMD: min  -1203.04  0.660518  0.660518  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1203.04  0.660518  0.660518  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1001.91  0.660518  0.660518  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8052 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -1002.77  0.660518  0.660518  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -987.127  0.660518  0.660518  0.31955
# protocols.relax.FastRelax: CMD: min  -1043.19  0.458695  0.458695  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1043.19  0.458695  0.458695  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -872.054  0.458695  0.458695  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 7873 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -872.36  0.458695  0.458695  0.55
# protocols.relax.FastRelax: CMD: min  -918.7  0.371714  0.371714  0.55
# protocols.relax.FastRelax: MRP: 4  -918.7  -918.7  0.371714  0.371714
# protocols.relax.FastRelax: CMD: accept_to_best  -918.7  0.371714  0.371714  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -918.7  0.371714  0.371714  0.55
# protocols::checkpoint: Deleting checkpoints of FastRelax
# ---------------------------------------------------------------------------------------------------------------> I439V
# core.scoring.ScoreFunctionFactory: SCOREFUNCTION: ref2015
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 3 rotamers at 1 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# protocols.relax.FastRelax: CMD: repeat  -910.017  0  0  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  -910.017  0  0  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1161.62  0  0  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 9521 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -1201.36  0  0  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1192.75  0  0  0.02805
# protocols.relax.FastRelax: CMD: min  -1504.26  1.1124  1.1124  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1504.26  1.1124  1.1124  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -751.362  1.1124  1.1124  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8516 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -809.663  1.1124  1.1124  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -764.431  1.1124  1.1124  0.154
# protocols.relax.FastRelax: CMD: min  -1191.38  0.564062  0.564062  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1191.38  0.564062  0.564062  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -992.829  0.564062  0.564062  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8194 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -991.888  0.564062  0.564062  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -976.581  0.564062  0.564062  0.31955
# protocols.relax.FastRelax: CMD: min  -1038.3  0.299938  0.299938  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1038.3  0.299938  0.299938  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -874.444  0.299938  0.299938  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 7954 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -875.534  0.299938  0.299938  0.55
# protocols.relax.FastRelax: CMD: min  -911.143  0.161269  0.161269  0.55
# protocols.relax.FastRelax: MRP: 0  -911.143  -911.143  0.161269  0.161269
# protocols.relax.FastRelax: CMD: accept_to_best  -911.143  0.161269  0.161269  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -911.143  0.161269  0.161269  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  -911.143  0.161269  0.161269  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1160.04  0.161269  0.161269  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 9389 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -1196.89  0.161269  0.161269  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1188.45  0.161269  0.161269  0.02805
# protocols.relax.FastRelax: CMD: min  -1500.71  1.12629  1.12629  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1500.71  1.12629  1.12629  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -738.751  1.12629  1.12629  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8461 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -805.12  1.12629  1.12629  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -758.599  1.12629  1.12629  0.154
# protocols.relax.FastRelax: CMD: min  -1195.91  0.568233  0.568233  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1195.91  0.568233  0.568233  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -997.842  0.568233  0.568233  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8166 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -998.673  0.568233  0.568233  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -983.325  0.568233  0.568233  0.31955
# protocols.relax.FastRelax: CMD: min  -1040.41  0.322952  0.322952  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1040.41  0.322952  0.322952  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -874.415  0.322952  0.322952  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 7963 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -874.621  0.322952  0.322952  0.55
# protocols.relax.FastRelax: CMD: min  -914.582  0.15727  0.15727  0.55
# protocols.relax.FastRelax: MRP: 1  -914.582  -914.582  0.15727  0.15727
# protocols.relax.FastRelax: CMD: accept_to_best  -914.582  0.15727  0.15727  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -914.582  0.15727  0.15727  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  -914.582  0.15727  0.15727  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1162.7  0.15727  0.15727  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 9446 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -1198.6  0.15727  0.15727  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1189.73  0.15727  0.15727  0.02805
# protocols.relax.FastRelax: CMD: min  -1508.9  1.11855  1.11855  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1508.9  1.11855  1.11855  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -751.279  1.11855  1.11855  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8480 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -808.628  1.11855  1.11855  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -762.681  1.11855  1.11855  0.154
# protocols.relax.FastRelax: CMD: min  -1194.38  0.565212  0.565212  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1194.38  0.565212  0.565212  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -994.743  0.565212  0.565212  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8130 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -995.85  0.565212  0.565212  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -980.395  0.565212  0.565212  0.31955
# protocols.relax.FastRelax: CMD: min  -1035.18  0.332902  0.332902  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1035.18  0.332902  0.332902  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -862.961  0.332902  0.332902  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 7885 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -863.145  0.332902  0.332902  0.55
# protocols.relax.FastRelax: CMD: min  -912.714  0.183874  0.183874  0.55
# protocols.relax.FastRelax: MRP: 2  -912.714  -914.582  0.15727  0.15727
# protocols.relax.FastRelax: CMD: accept_to_best  -912.714  0.183874  0.183874  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -912.714  0.183874  0.183874  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  -912.714  0.183874  0.183874  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1161.06  0.183874  0.183874  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 9453 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -1203.07  0.183874  0.183874  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1194.98  0.183874  0.183874  0.02805
# protocols.relax.FastRelax: CMD: min  -1508.37  1.1247  1.1247  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1508.37  1.1247  1.1247  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -753.429  1.1247  1.1247  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8371 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -809.659  1.1247  1.1247  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -763.147  1.1247  1.1247  0.154
# protocols.relax.FastRelax: CMD: min  -1195.66  0.546938  0.546938  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1195.66  0.546938  0.546938  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -994.566  0.546938  0.546938  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8166 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -995.817  0.546938  0.546938  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -980.18  0.546938  0.546938  0.31955
# protocols.relax.FastRelax: CMD: min  -1038.92  0.290455  0.290455  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1038.92  0.290455  0.290455  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -869.714  0.290455  0.290455  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 7923 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -870.566  0.290455  0.290455  0.55
# protocols.relax.FastRelax: CMD: min  -913.18  0.191915  0.191915  0.55
# protocols.relax.FastRelax: MRP: 3  -913.18  -914.582  0.15727  0.15727
# protocols.relax.FastRelax: CMD: accept_to_best  -913.18  0.191915  0.191915  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -913.18  0.191915  0.191915  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  -913.18  0.191915  0.191915  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1164.24  0.191915  0.191915  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 9495 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -1202.29  0.191915  0.191915  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -1193.87  0.191915  0.191915  0.02805
# protocols.relax.FastRelax: CMD: min  -1509.73  1.13158  1.13158  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1509.73  1.13158  1.13158  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -755.476  1.13158  1.13158  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8401 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -806.228  1.13158  1.13158  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -760.276  1.13158  1.13158  0.154
# protocols.relax.FastRelax: CMD: min  -1189.9  0.561429  0.561429  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1189.9  0.561429  0.561429  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -988.512  0.561429  0.561429  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 8086 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -991.655  0.561429  0.561429  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -976.1  0.561429  0.561429  0.31955
# protocols.relax.FastRelax: CMD: min  -1038.44  0.324484  0.324484  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -1038.44  0.324484  0.324484  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -872.365  0.324484  0.324484  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 7937 rotamers at 331 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -872.667  0.324484  0.324484  0.55
# protocols.relax.FastRelax: CMD: min  -913.286  0.309126  0.309126  0.55
# protocols.relax.FastRelax: MRP: 4  -913.286  -914.582  0.15727  0.15727
# protocols.relax.FastRelax: CMD: accept_to_best  -913.286  0.309126  0.309126  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -913.286  0.309126  0.309126  0.55
# protocols::checkpoint: Deleting checkpoints of FastRelax
# CPU times: user 21min 24s, sys: 4.02 s, total: 21min 28s
# Wall time: 21min 29s
